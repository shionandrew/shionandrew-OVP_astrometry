# %%
tec_grid = np.arange(-40,40,.01)

event_id=436928449
SNR_THRESH=30
tel='hco'
baseline_name=f'chime-{tel}'
out_dir=f'/arc/projects/chime_frb/vlbi/OVP_astrometry_{tel}_F11/{tag}/{event_id}/calibrated/'
